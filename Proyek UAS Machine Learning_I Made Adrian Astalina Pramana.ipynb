# %%
# Mengimpor library yang dibutuhkan
import pandas as pd
import mlxtend as mlxtend
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# Memanggil dan menampilkan data dalam bentuk DataFrame
fileLocation = 'C:/Users/adria/Downloads/Pertemuan 16 (UAS MACHINE LEARNING)/Dataset/Grocery_Dataset.xlsx'
df = pd.read_excel(fileLocation)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Mengecek atribut (features)
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %% [markdown]
# # Data Understanding

# %%
# Mengecek tipe data di setiap atributnya
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
# Menampilkan atribut yang memiliki nilai null
df.isnull().sum().sort_values(ascending=False)
# Out:
# CustomerID     135080
# Description      1454
# InvoiceNo           0
# StockCode           0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# Country             0
# dtype: int64

# %% [markdown]
# # Data Preparation

# %%
# Menghapus atribut yang tidak diperlukan
dataset = df.drop(['StockCode', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country'], axis=1)

# Menghapus Missing Values Pada Dataset
dataset.dropna(axis=0, subset=['Description'], inplace=True)

# Konversi kolom 'InvoiceNo' menjadi string dan Hapus Karakter 'C' (Cancelled Transaction) dan 'A' (Adjust Bad Debt)
df['InvoiceNo'] = df['InvoiceNo'].astype(str)
mask = df['InvoiceNo'].str.contains('[CA]')

# Filter DataFrame untuk menghapus baris yang mengandung 'C' atau 'A'
dataset = df[~mask]
dataset
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# Melakukan Transformasi Data
itemset = dataset.groupby(['InvoiceNo', 'Description']).size().reset_index(name='count')
basket = (itemset.groupby(['InvoiceNo', 'Description'])['count']
         .sum().unstack().reset_index().fillna(0)
         .set_index('InvoiceNo'))
basket
# Out:
# Description  20713   4 PURPLE FLOCK DINNER CANDLES  \
# InvoiceNo
# 536365         0.0                             0.0
# 536366         0.0                             0.0
# 536367         0.0                             0.0
# 536368         0.0                             0.0
# 536369         0.0                             0.0
# ...            ...                             ...
# 581583         0.0                             0.0
# 581584         0.0                             0.0
# 581585         0.0                             0.0
# 581586         0.0                             0.0
# 581587         0.0                             0.0
#
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536365                                  0.0                 0.0
# 536366                                  0.0                 0.0
# 536367                                  0.0                 0.0
# 536368                                  0.0                 0.0
# ...

# %%
# Melakukan Encoding Data
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
basket_sets = basket.applymap(encode_units)
basket_sets
# Out:
# Description  20713   4 PURPLE FLOCK DINNER CANDLES  \
# InvoiceNo
# 536365           0                               0
# 536366           0                               0
# 536367           0                               0
# 536368           0                               0
# 536369           0                               0
# ...            ...                             ...
# 581583           0                               0
# 581584           0                               0
# 581585           0                               0
# 581586           0                               0
# 581587           0                               0
#
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536365                                    0                   0
# 536366                                    0                   0
# 536367                                    0                   0
# 536368                                    0                   0
# ...

# %%
# Melakukan Filter Transaksi yang lebih besar sama dengan 2 item
basket_filter = basket_sets[(basket_sets > 0).sum(axis=1) >= 2]
basket_filter
# Out:
# Description  20713   4 PURPLE FLOCK DINNER CANDLES  \
# InvoiceNo
# 536365           0                               0
# 536366           0                               0
# 536367           0                               0
# 536368           0                               0
# 536370           0                               0
# ...            ...                             ...
# 581583           0                               0
# 581584           0                               0
# 581585           0                               0
# 581586           0                               0
# 581587           0                               0
#
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536365                                    0                   0
# 536366                                    0                   0
# 536367                                    0                   0
# 536368                                    0                   0
# ...

# %% [markdown]
# # Membentuk Model

# %%
# Membentuk Frequent Itemsets
frequent_itemsets = apriori(basket_sets.astype('bool'), min_support=0.02, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#       support                                           itemsets  length
# 0    0.022711                         (3 STRIPEY MICE FELTCRAFT)       1
# 1    0.023487                      (4 TRADITIONAL SPINNING TOPS)       1
# 2    0.046343                           (6 RIBBONS RUSTIC CHARM)       1
# 3    0.021206                  (60 CAKE CASES DOLLY GIRL DESIGN)       1
# 4    0.029990                  (60 CAKE CASES VINTAGE CHRISTMAS)       1
# ..        ...                                                ...     ...
# 347  0.024555  (RED RETROSPOT CHARLOTTE BAG, WOODLAND CHARLOT...       2
# 348  0.025477  (REGENCY CAKESTAND 3 TIER, ROSES REGENCY TEACU...       2
# 349  0.026156  (WOODEN FRAME ANTIQUE WHITE , WOODEN PICTURE F...       2
# 350  0.026302  (ROSES REGENCY TEACUP AND SAUCER , GREEN REGEN...       3
# 351  0.020042  (JUMBO BAG PINK POLKADOT, JUMBO BAG RED RETROS...       3
#
# [352 rows x 3 columns]

# %%
# Membentuk Atuaran Asosiasi (Association Rules) dari Itemsets yang telah dihasilkan
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
results = rules[['antecedents', 'consequents', 'support', 'confidence']]
results
# Out:
#                                           antecedents  \
# 0                       (CHARLOTTE BAG PINK POLKADOT)
# 1                (GARDENERS KNEELING PAD CUP OF TEA )
# 2                    (PINK REGENCY TEACUP AND SAUCER)
# 3                  (ROSES REGENCY TEACUP AND SAUCER )
# 4                   (GREEN REGENCY TEACUP AND SAUCER)
# 5                    (PINK REGENCY TEACUP AND SAUCER)
# 6   (ROSES REGENCY TEACUP AND SAUCER , GREEN REGEN...
# 7   (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...
# 8   (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 9                    (PINK REGENCY TEACUP AND SAUCER)
# 10  (JUMBO BAG PINK POLKADOT, JUMBO STORAGE BAG SUKI)
#
#                                           consequents   support  confidence
# 0                       (RED RETROSPOT CHARLOTTE BAG)  0.025331    0.702557
# 1                 (GARDENERS KNEELING PAD KEEP CALM )  0.026496    0.720317
# 2                   (GREEN REGENCY TEACUP AND SAUCER)  0.030718    0.826371
# ...

# %% [markdown]
# # Mengevaluasi Model

# %%
# Mengevaluasi Model dengan Lift Ratio
results = rules[(rules['confidence'] >= 0.7) &
               (rules['lift'] > 1)]
apriori_result = results.sort_values(by='lift', ascending=False)
apriori_result[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
# Out:
#                                           antecedents  \
# 6   (ROSES REGENCY TEACUP AND SAUCER , GREEN REGEN...
# 9                    (PINK REGENCY TEACUP AND SAUCER)
# 7   (ROSES REGENCY TEACUP AND SAUCER , PINK REGENC...
# 2                    (PINK REGENCY TEACUP AND SAUCER)
# 8   (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 1                (GARDENERS KNEELING PAD CUP OF TEA )
# 5                    (PINK REGENCY TEACUP AND SAUCER)
# 3                  (ROSES REGENCY TEACUP AND SAUCER )
# 4                   (GREEN REGENCY TEACUP AND SAUCER)
# 0                       (CHARLOTTE BAG PINK POLKADOT)
# 10  (JUMBO BAG PINK POLKADOT, JUMBO STORAGE BAG SUKI)
#
#                                           consequents   support  confidence  \
# 6                    (PINK REGENCY TEACUP AND SAUCER)  0.026302    0.705729
# 9   (ROSES REGENCY TEACUP AND SAUCER , GREEN REGEN...  0.026302    0.707572
# 7                   (GREEN REGENCY TEACUP AND SAUCER)  0.026302    0.904841
# ...
